# %%
# create one class
# one attribute saves name
# one method welcome(name): return f'welcome {name}!!!'

class funthing:
  def __init__(self, name):
    self.name = name

def welcome(self):
  return f'Welcome (name)!!!'

welcome('Syazwan')
# Out:
# 'Welcome (name)!!!'

# %%
class SelamatDatang:
    name = "Syazwan"

    def welcome(self,name):
        return f'Selamat Datang: {name}!!'

# %%
SelamatDatang.welcome(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 SelamatDatang.welcome(name)
#
# NameError: name 'name' is not defined
